# %% [markdown]
# <a href="https://colab.research.google.com/github/aasharib/CV_Assignment_3/blob/main/CV_Assignment_3_simple_vgg_val_84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!unzip -q /content/drive/MyDrive/Semester1/CV/Assignment/3/intel-image-classification.zip -d /content/assgn3

# %%
from sklearn.datasets import load_files
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
trainData = load_files('/content/assgn3/seg_train/seg_train',load_content=False)
testData = load_files('/content/assgn3/seg_test/seg_test',load_content=False)
#validationData = load_files('/content/assgn3/seg_pred/seg_pred',load_content=False)

# %%
trainData
# Out:
# {'DESCR': None,
#  'filenames': array(['/content/assgn3/seg_train/seg_train/glacier/6416.jpg',
#         '/content/assgn3/seg_train/seg_train/buildings/5658.jpg',
#         '/content/assgn3/seg_train/seg_train/street/7656.jpg', ...,
#         '/content/assgn3/seg_train/seg_train/sea/13907.jpg',
#         '/content/assgn3/seg_train/seg_train/sea/3467.jpg',
#         '/content/assgn3/seg_train/seg_train/forest/14133.jpg'],
#        dtype='<U55'),
#  'target': array([2, 0, 5, ..., 4, 4, 1]),
#  'target_names': ['buildings',
#   'forest',
#   'glacier',
#   'mountain',
#   'sea',
#   'street']}

# %%
trainDataLabel = trainData.target

# %%
def readAndPreprocessImage(imgFile):
    curImg = np.asarray(Image.open(imgFile).resize((150,150)))
    if curImg is not None:
        #print("Done", imgFile)
        return curImg

# %%
trainDataImgArr = np.array(list(map(readAndPreprocessImage, trainData.filenames)))

# %%
(trainingDataImgX, validationDataImgX, trainingDataLabelY, validationDataLabelY) = train_test_split(trainDataImgArr, trainDataLabel, test_size=0.2, random_state=42)

# %%
fig, ax = plt.subplots(1,2,figsize=(6,6))
ax[0].imshow(trainingDataImgX[0])
ax[1].imshow(trainingDataImgX[1])
print(trainingDataLabelY[0])
print(trainingDataLabelY[1])
# Out:
# 2
# 3

# %%
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, Dropout
from keras.models import Sequential

vgg16 = Sequential()
vgg16.add(Conv2D(64, kernel_size=3, padding='same', activation='relu',
                 input_shape=(150, 150, 3)))
vgg16.add(Conv2D(64, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(128, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(128, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
vgg16.add(Dropout(0.25))

vgg16.add(Flatten())

vgg16.add(Dense(4096, activation='relu'))
vgg16.add(Dense(4096, activation='relu'))
vgg16.add(Dense(4096, activation='relu'))

# the data we are using has 6 classes
vgg16.add(Dense(6, activation='softmax'))

# %%
#vgg16.summary()

# %%
from keras.optimizers import SGD
sgd = SGD(lr=0.001, decay=1e-7, momentum=.9)
vgg16.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              metrics=['accuracy'])

# %%
trainingDataLabelY[0]
# Out:
# 2

# %%
from keras.utils import to_categorical
trainingDataLabelOHE = to_categorical(trainingDataLabelY)
validationDataLabelOHE = to_categorical(validationDataLabelY)

# %%
trainingDataLabelOHE[0]
# Out:
# array([0., 0., 1., 0., 0., 0.], dtype=float32)

# %%
H = vgg16.fit(trainingDataImgX, trainingDataLabelOHE, batch_size=128, epochs=50, validation_data=(validationDataImgX, validationDataLabelOHE))
# Out:
# Epoch 1/50
# 88/88 [==============================] - 91s 938ms/step - loss: 1.7838 - accuracy: 0.1928 - val_loss: 1.5012 - val_accuracy: 0.3684
# Epoch 2/50
# 88/88 [==============================] - 74s 846ms/step - loss: 1.3739 - accuracy: 0.4363 - val_loss: 1.2578 - val_accuracy: 0.4735
# Epoch 3/50
# 88/88 [==============================] - 74s 846ms/step - loss: 1.1371 - accuracy: 0.5434 - val_loss: 1.0884 - val_accuracy: 0.5807
# Epoch 4/50
# 88/88 [==============================] - 74s 846ms/step - loss: 1.0565 - accuracy: 0.5739 - val_loss: 1.0579 - val_accuracy: 0.5650
# Epoch 5/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.9975 - accuracy: 0.6005 - val_loss: 1.0376 - val_accuracy: 0.6046
# Epoch 6/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.9722 - accuracy: 0.6069 - val_loss: 1.0953 - val_accuracy: 0.5586
# Epoch 7/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.9262 - accuracy: 0.6309 - val_loss: 0.9971 - val_accuracy: 0.6274
# Epoch 8/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.8899 - accuracy: 0.6524 - val_loss: 1.1044 - val_accuracy: 0.5860
# Epoch 9/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.8498 - accuracy: 0.6654 - val_loss: 1.0747 - val_accuracy: 0.5775
# Epoch 10/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.7941 - accuracy: 0.6937 - val_loss: 0.9770 - val_accuracy: 0.6370
# Epoch 11/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.7366 - accuracy: 0.7247 - val_loss: 0.8710 - val_accuracy: 0.6933
# Epoch 12/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.7398 - accuracy: 0.7363 - val_loss: 0.7363 - val_accuracy: 0.7268
# Epoch 13/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.6778 - accuracy: 0.7523 - val_loss: 0.7063 - val_accuracy: 0.7496
# Epoch 14/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.6855 - accuracy: 0.7495 - val_loss: 0.7099 - val_accuracy: 0.7435
# Epoch 15/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.6281 - accuracy: 0.7690 - val_loss: 0.7477 - val_accuracy: 0.7389
# Epoch 16/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.5990 - accuracy: 0.7793 - val_loss: 0.7275 - val_accuracy: 0.7446
# Epoch 17/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.5884 - accuracy: 0.7885 - val_loss: 0.6735 - val_accuracy: 0.7652
# Epoch 18/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.5857 - accuracy: 0.7923 - val_loss: 0.6848 - val_accuracy: 0.7631
# Epoch 19/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.5473 - accuracy: 0.7988 - val_loss: 0.5994 - val_accuracy: 0.7923
# Epoch 20/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.5358 - accuracy: 0.8056 - val_loss: 0.5881 - val_accuracy: 0.8012
# Epoch 21/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.5105 - accuracy: 0.8222 - val_loss: 0.7042 - val_accuracy: 0.7556
# Epoch 22/50
# 88/88 [==============================] - 74s 844ms/step - loss: 0.5136 - accuracy: 0.8152 - val_loss: 0.6060 - val_accuracy: 0.7919
# Epoch 23/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.5237 - accuracy: 0.8130 - val_loss: 0.5247 - val_accuracy: 0.8219
# Epoch 24/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.4919 - accuracy: 0.8261 - val_loss: 0.5639 - val_accuracy: 0.8094
# Epoch 25/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.4736 - accuracy: 0.8306 - val_loss: 0.5798 - val_accuracy: 0.8005
# Epoch 26/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4654 - accuracy: 0.8340 - val_loss: 0.5153 - val_accuracy: 0.8343
# Epoch 27/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4488 - accuracy: 0.8391 - val_loss: 0.4850 - val_accuracy: 0.8404
# Epoch 28/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4362 - accuracy: 0.8430 - val_loss: 0.5164 - val_accuracy: 0.8180
# Epoch 29/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4298 - accuracy: 0.8462 - val_loss: 0.5721 - val_accuracy: 0.8041
# Epoch 30/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4749 - accuracy: 0.8351 - val_loss: 0.5176 - val_accuracy: 0.8294
# Epoch 31/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4281 - accuracy: 0.8426 - val_loss: 0.5771 - val_accuracy: 0.7980
# Epoch 32/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4225 - accuracy: 0.8544 - val_loss: 0.5476 - val_accuracy: 0.8123
# Epoch 33/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4137 - accuracy: 0.8518 - val_loss: 0.5109 - val_accuracy: 0.8304
# Epoch 34/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.4198 - accuracy: 0.8490 - val_loss: 0.5409 - val_accuracy: 0.8183
# Epoch 35/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3904 - accuracy: 0.8581 - val_loss: 0.4680 - val_accuracy: 0.8368
# Epoch 36/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3853 - accuracy: 0.8588 - val_loss: 0.4975 - val_accuracy: 0.8297
# Epoch 37/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3736 - accuracy: 0.8653 - val_loss: 0.4572 - val_accuracy: 0.8550
# Epoch 38/50
# 88/88 [==============================] - 74s 844ms/step - loss: 0.3855 - accuracy: 0.8621 - val_loss: 0.4985 - val_accuracy: 0.8286
# Epoch 39/50
# 88/88 [==============================] - 74s 847ms/step - loss: 0.3618 - accuracy: 0.8664 - val_loss: 0.4824 - val_accuracy: 0.8318
# Epoch 40/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3453 - accuracy: 0.8767 - val_loss: 0.4725 - val_accuracy: 0.8379
# Epoch 41/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3455 - accuracy: 0.8795 - val_loss: 0.4711 - val_accuracy: 0.8440
# Epoch 42/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3341 - accuracy: 0.8756 - val_loss: 0.4765 - val_accuracy: 0.8432
# Epoch 43/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3370 - accuracy: 0.8772 - val_loss: 0.4766 - val_accuracy: 0.8354
# Epoch 44/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3236 - accuracy: 0.8849 - val_loss: 0.4663 - val_accuracy: 0.8436
# Epoch 45/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.3207 - accuracy: 0.8846 - val_loss: 0.4809 - val_accuracy: 0.8308
# Epoch 46/50
# 88/88 [==============================] - 74s 845ms/step - loss: 0.3303 - accuracy: 0.8773 - val_loss: 0.4658 - val_accuracy: 0.8425
# Epoch 47/50
# 88/88 [==============================] - 74s 847ms/step - loss: 0.2975 - accuracy: 0.8885 - val_loss: 0.4859 - val_accuracy: 0.8315
# Epoch 48/50
# 88/88 [==============================] - 74s 846ms/step - loss: 0.2839 - accuracy: 0.8958 - val_loss: 0.4603 - val_accuracy: 0.8425
# Epoch 49/50
# 88/88 [==============================] - 74s 847ms/step - loss: 0.2998 - accuracy: 0.8855 - val_loss: 0.4518 - val_accuracy: 0.8504
# Epoch 50/50
# 88/88 [==============================] - 74s 847ms/step - loss: 0.2736 - accuracy: 0.8996 - val_loss: 0.4446 - val_accuracy: 0.8468

# %%
# save the model's trained weights
vgg16.save_weights('vgg16_trained_50epochs_normal_vgg_with_validation.h5')

# %%
# !cp /content/vgg16_trained_normal_vgg.h5 /content/drive/MyDrive/Semester1/CV/Assignment/3

# %%
import matplotlib.pyplot as plt
N = np.arange(0, 50)
plt.style.use('ggplot')
plt.figure()
plt.plot(N, H.history['loss'], label='train_loss')
plt.plot(N, H.history['val_loss'], label='val_loss')
plt.plot(N, H.history['accuracy'], label='train_accuracy')
plt.plot(N, H.history['val_accuracy'], label='val_accuracy')
plt.title('Training loss and accuracy')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show()

# %%
testDataImgArr = np.array(list(map(readAndPreprocessImage, testData.filenames)))
testDataLabel = testData.target
testDataLabelOHE = to_categorical(testDataLabel)

# %%
'''CONFUSION MATRIX'''
# Making prediction
predicatedTestDataY = vgg16.predict_classes(testDataImgArr)
actualTestDataY = np.argmax(testDataLabelOHE, axis=-1)

# Plotting the confusion matrix
from sklearn.metrics import confusion_matrix
confusionMatrix = confusion_matrix(actualTestDataY, predicatedTestDataY)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(confusionMatrix)
# Out:
# [[363   9   0   6   7  52]
#  [  0 460   3   6   1   4]
#  [  2   5 427  77  36   6]
#  [  0   5  65 420  35   0]
#  [  7   4  22  14 453  10]
#  [ 48  20   0   4   3 426]]
