# %% [markdown]
# <a href="https://colab.research.google.com/github/aasharib/CV_Assignment_3/blob/main/CV_Assignment_3_vgg_without_dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -q /content/drive/MyDrive/Semester1/CV/Assignment/3/intel-image-classification.zip -d /content/assgn3
# Out:
# replace /content/assgn3/seg_pred/seg_pred/10004.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: no
# replace /content/assgn3/seg_pred/seg_pred/10005.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: Nono

# %%
from sklearn.datasets import load_files
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
trainData = load_files('/content/assgn3/seg_train/seg_train',load_content=False)
testData = load_files('/content/assgn3/seg_test/seg_test',load_content=False)
#validationData = load_files('/content/assgn3/seg_pred/seg_pred',load_content=False)

# %%
trainData
# Out:
# {'DESCR': None,
#  'filenames': array(['/content/assgn3/seg_train/seg_train/glacier/6416.jpg',
#         '/content/assgn3/seg_train/seg_train/buildings/5658.jpg',
#         '/content/assgn3/seg_train/seg_train/street/7656.jpg', ...,
#         '/content/assgn3/seg_train/seg_train/sea/13907.jpg',
#         '/content/assgn3/seg_train/seg_train/sea/3467.jpg',
#         '/content/assgn3/seg_train/seg_train/forest/14133.jpg'],
#        dtype='<U55'),
#  'target': array([2, 0, 5, ..., 4, 4, 1]),
#  'target_names': ['buildings',
#   'forest',
#   'glacier',
#   'mountain',
#   'sea',
#   'street']}

# %%
trainDataLabel = trainData.target

# %%
def readAndPreprocessImage(imgFile):
    curImg = np.asarray(Image.open(imgFile).resize((150,150)))
    if curImg is not None:
        #print("Done", imgFile)
        return curImg

# %%
trainDataImgArr = np.array(list(map(readAndPreprocessImage, trainData.filenames)))

# %%
(trainingDataImgX, validationDataImgX, trainingDataLabelY, validationDataLabelY) = train_test_split(trainDataImgArr, trainDataLabel, test_size=0.2, random_state=42)

# %%
fig, ax = plt.subplots(1,2,figsize=(6,6))
ax[0].imshow(trainingDataImgX[0])
ax[1].imshow(trainingDataImgX[1])
print(trainingDataLabelY[0])
print(trainingDataLabelY[1])
# Out:
# 2
# 3

# %%
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, Dropout
from keras.models import Sequential

vgg16 = Sequential()
vgg16.add(Conv2D(64, kernel_size=3, padding='same', activation='relu',
                 input_shape=(150, 150, 3)))
vgg16.add(Conv2D(64, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(128, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(128, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Flatten())

vgg16.add(Dense(4096, activation='relu'))
vgg16.add(Dense(4096, activation='relu'))
vgg16.add(Dense(4096, activation='relu'))

# the data we are using has 6 classes
vgg16.add(Dense(6, activation='softmax'))

# %%
vgg16.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 37, 37, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 18, 18, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 18, 18, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 18, 18, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              2101248
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 24582
# =================================================================
# Total params: 50,403,142
# Trainable params: 50,403,142
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import SGD
sgd = SGD(lr=0.001, decay=1e-7, momentum=.9)
vgg16.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              metrics=['accuracy'])

# %%
trainingDataLabelY[0]
# Out:
# 2

# %%
from keras.utils import to_categorical
trainingDataLabelOHE = to_categorical(trainingDataLabelY)
validationDataLabelOHE = to_categorical(validationDataLabelY)

# %%
trainingDataLabelOHE[0]
# Out:
# array([0., 0., 1., 0., 0., 0.], dtype=float32)

# %%
H = vgg16.fit(trainingDataImgX, trainingDataLabelOHE, batch_size=256, epochs=50, validation_data=(validationDataImgX, validationDataLabelOHE))
# Out:
# Epoch 1/50
# 44/44 [==============================] - 98s 2s/step - loss: 1.7641 - accuracy: 0.2395 - val_loss: 1.7758 - val_accuracy: 0.2512
# Epoch 2/50
# 44/44 [==============================] - 72s 2s/step - loss: 1.7467 - accuracy: 0.2480 - val_loss: 1.5058 - val_accuracy: 0.4400
# Epoch 3/50
# 44/44 [==============================] - 73s 2s/step - loss: 1.4259 - accuracy: 0.4380 - val_loss: 1.1549 - val_accuracy: 0.5607
# Epoch 4/50
# 44/44 [==============================] - 73s 2s/step - loss: 1.1450 - accuracy: 0.5497 - val_loss: 1.1938 - val_accuracy: 0.5102
# Epoch 5/50
# 44/44 [==============================] - 73s 2s/step - loss: 1.1166 - accuracy: 0.5495 - val_loss: 1.0361 - val_accuracy: 0.5900
# Epoch 6/50
# 44/44 [==============================] - 73s 2s/step - loss: 1.0186 - accuracy: 0.6030 - val_loss: 1.0029 - val_accuracy: 0.5996
# Epoch 7/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.9557 - accuracy: 0.6261 - val_loss: 1.0412 - val_accuracy: 0.5832
# Epoch 8/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.9394 - accuracy: 0.6311 - val_loss: 1.0035 - val_accuracy: 0.6049
# Epoch 9/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.9201 - accuracy: 0.6307 - val_loss: 0.9059 - val_accuracy: 0.6352
# Epoch 10/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.8680 - accuracy: 0.6628 - val_loss: 0.8263 - val_accuracy: 0.6858
# Epoch 11/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.8366 - accuracy: 0.6738 - val_loss: 0.8195 - val_accuracy: 0.6836
# Epoch 12/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.7884 - accuracy: 0.6960 - val_loss: 0.8645 - val_accuracy: 0.6673
# Epoch 13/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.7323 - accuracy: 0.7223 - val_loss: 0.7906 - val_accuracy: 0.7000
# Epoch 14/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.7415 - accuracy: 0.7189 - val_loss: 0.7443 - val_accuracy: 0.7221
# Epoch 15/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.7416 - accuracy: 0.7187 - val_loss: 0.7613 - val_accuracy: 0.7075
# Epoch 16/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.6833 - accuracy: 0.7468 - val_loss: 0.7093 - val_accuracy: 0.7435
# Epoch 17/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.6310 - accuracy: 0.7608 - val_loss: 0.7345 - val_accuracy: 0.7221
# Epoch 18/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.6322 - accuracy: 0.7673 - val_loss: 0.6684 - val_accuracy: 0.7599
# Epoch 19/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.5824 - accuracy: 0.7876 - val_loss: 0.8087 - val_accuracy: 0.6804
# Epoch 20/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.6085 - accuracy: 0.7730 - val_loss: 0.6725 - val_accuracy: 0.7478
# Epoch 21/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.5753 - accuracy: 0.7859 - val_loss: 0.6716 - val_accuracy: 0.7517
# Epoch 22/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.5372 - accuracy: 0.8030 - val_loss: 0.7476 - val_accuracy: 0.7246
# Epoch 23/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.5044 - accuracy: 0.8160 - val_loss: 0.5731 - val_accuracy: 0.7973
# Epoch 24/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.4530 - accuracy: 0.8320 - val_loss: 0.6054 - val_accuracy: 0.7830
# Epoch 25/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.4308 - accuracy: 0.8420 - val_loss: 0.6073 - val_accuracy: 0.7838
# Epoch 26/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.4366 - accuracy: 0.8462 - val_loss: 0.6098 - val_accuracy: 0.7912
# Epoch 27/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.4059 - accuracy: 0.8486 - val_loss: 0.5717 - val_accuracy: 0.8019
# Epoch 28/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.3632 - accuracy: 0.8687 - val_loss: 0.6108 - val_accuracy: 0.7862
# Epoch 29/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.3761 - accuracy: 0.8630 - val_loss: 0.5962 - val_accuracy: 0.7959
# Epoch 30/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.3494 - accuracy: 0.8721 - val_loss: 0.7426 - val_accuracy: 0.7545
# Epoch 31/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.3638 - accuracy: 0.8697 - val_loss: 0.6151 - val_accuracy: 0.8098
# Epoch 32/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.3400 - accuracy: 0.8785 - val_loss: 0.5755 - val_accuracy: 0.7980
# Epoch 33/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.2827 - accuracy: 0.9019 - val_loss: 0.6548 - val_accuracy: 0.7973
# Epoch 34/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.2332 - accuracy: 0.9161 - val_loss: 0.6397 - val_accuracy: 0.8001
# Epoch 35/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.2446 - accuracy: 0.9146 - val_loss: 0.6696 - val_accuracy: 0.7905
# Epoch 36/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.2431 - accuracy: 0.9154 - val_loss: 0.6884 - val_accuracy: 0.7902
# Epoch 37/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1845 - accuracy: 0.9330 - val_loss: 0.7236 - val_accuracy: 0.8009
# Epoch 38/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1969 - accuracy: 0.9259 - val_loss: 0.7205 - val_accuracy: 0.7873
# Epoch 39/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1643 - accuracy: 0.9438 - val_loss: 0.7857 - val_accuracy: 0.7738
# Epoch 40/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1872 - accuracy: 0.9377 - val_loss: 0.5837 - val_accuracy: 0.8037
# Epoch 41/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1671 - accuracy: 0.9426 - val_loss: 0.9397 - val_accuracy: 0.7731
# Epoch 42/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1826 - accuracy: 0.9375 - val_loss: 0.9432 - val_accuracy: 0.7748
# Epoch 43/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1518 - accuracy: 0.9450 - val_loss: 0.8473 - val_accuracy: 0.8001
# Epoch 44/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1116 - accuracy: 0.9605 - val_loss: 1.0616 - val_accuracy: 0.7595
# Epoch 45/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1403 - accuracy: 0.9501 - val_loss: 0.7844 - val_accuracy: 0.7991
# Epoch 46/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.1277 - accuracy: 0.9549 - val_loss: 0.7636 - val_accuracy: 0.8073
# Epoch 47/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.0801 - accuracy: 0.9737 - val_loss: 1.0070 - val_accuracy: 0.7862
# Epoch 48/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.0782 - accuracy: 0.9720 - val_loss: 1.0058 - val_accuracy: 0.7919
# Epoch 49/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.0541 - accuracy: 0.9826 - val_loss: 1.0161 - val_accuracy: 0.8062
# Epoch 50/50
# 44/44 [==============================] - 73s 2s/step - loss: 0.0576 - accuracy: 0.9819 - val_loss: 1.1223 - val_accuracy: 0.7859

# %%
# save the model's trained weights
vgg16.save_weights('vgg_trained_without_dropout.h5')

# %%
#!cp /content/vgg16_trained_normal_vgg.h5 /content/drive/MyDrive/Semester1/CV/Assignment/3

# %%
import matplotlib.pyplot as plt
N = np.arange(0, 50)
plt.style.use('ggplot')
plt.figure()
plt.plot(N, H.history['loss'], label='train_loss')
plt.plot(N, H.history['val_loss'], label='val_loss')
plt.plot(N, H.history['accuracy'], label='train_accuracy')
plt.plot(N, H.history['val_accuracy'], label='val_accuracy')
plt.title('Training loss and accuracy')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show()

# %%
testDataImgArr = np.array(list(map(readAndPreprocessImage, testData.filenames)))
testDataLabel = testData.target
testDataLabelOHE = to_categorical(testDataLabel)

# %%
'''CONFUSION MATRIX'''
# Making prediction
predicatedTestDataY = vgg16.predict_classes(testDataImgArr)
actualTestDataY = np.argmax(testDataLabelOHE, axis=-1)

# Plotting the confusion matrix
from sklearn.metrics import confusion_matrix
confusionMatrix = confusion_matrix(actualTestDataY, predicatedTestDataY)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(confusionMatrix)
# Out:
# [[403   4   5   1   5  19]
#  [ 15 421   4   8   2  24]
#  [  9   4 409  78  48   5]
#  [ 14   3  76 400  31   1]
#  [ 16   3  51  38 400   2]
#  [166   3   3   6   3 320]]
