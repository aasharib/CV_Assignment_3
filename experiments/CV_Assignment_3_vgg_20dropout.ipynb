# %% [markdown]
# <a href="https://colab.research.google.com/github/aasharib/CV_Assignment_3/blob/main/CV_Assignment_3_vgg_20dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -q /content/drive/MyDrive/Semester1/CV/Assignment/3/intel-image-classification.zip -d /content/assgn3

# %%
from sklearn.datasets import load_files
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
trainData = load_files('/content/assgn3/seg_train/seg_train',load_content=False)
testData = load_files('/content/assgn3/seg_test/seg_test',load_content=False)
#validationData = load_files('/content/assgn3/seg_pred/seg_pred',load_content=False)

# %%
trainData
# Out:
# {'DESCR': None,
#  'filenames': array(['/content/assgn3/seg_train/seg_train/glacier/6416.jpg',
#         '/content/assgn3/seg_train/seg_train/buildings/5658.jpg',
#         '/content/assgn3/seg_train/seg_train/street/7656.jpg', ...,
#         '/content/assgn3/seg_train/seg_train/sea/13907.jpg',
#         '/content/assgn3/seg_train/seg_train/sea/3467.jpg',
#         '/content/assgn3/seg_train/seg_train/forest/14133.jpg'],
#        dtype='<U55'),
#  'target': array([2, 0, 5, ..., 4, 4, 1]),
#  'target_names': ['buildings',
#   'forest',
#   'glacier',
#   'mountain',
#   'sea',
#   'street']}

# %%
trainDataLabel = trainData.target

# %%
def readAndPreprocessImage(imgFile):
    curImg = np.asarray(Image.open(imgFile).resize((150,150)))
    if curImg is not None:
        #print("Done", imgFile)
        return curImg

# %%
trainDataImgArr = np.array(list(map(readAndPreprocessImage, trainData.filenames)))

# %%
(trainingDataImgX, validationDataImgX, trainingDataLabelY, validationDataLabelY) = train_test_split(trainDataImgArr, trainDataLabel, test_size=0.2, random_state=42)

# %%
fig, ax = plt.subplots(1,2,figsize=(6,6))
ax[0].imshow(trainingDataImgX[0])
ax[1].imshow(trainingDataImgX[1])
print(trainingDataLabelY[0])
print(trainingDataLabelY[1])
# Out:
# 2
# 3

# %%
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, Dropout
from keras.models import Sequential

vgg16 = Sequential()
vgg16.add(Conv2D(64, kernel_size=3, padding='same', activation='relu',
                 input_shape=(150, 150, 3)))
vgg16.add(Conv2D(64, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(128, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(128, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(256, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, padding='same', activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(Conv2D(512, kernel_size=3, activation='relu'))
vgg16.add(MaxPooling2D(pool_size=2, strides=2))
#vgg16.add(Dropout(0.25))

vgg16.add(Flatten())

vgg16.add(Dense(4096, activation='relu'))
vgg16.add(Dense(4096, activation='relu'))
vgg16.add(Dense(4096, activation='relu'))

# the data we are using has 6 classes
vgg16.add(Dense(6, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-5d49b600d4ef> in <module>()
#       2 from keras.models import Sequential
#       3
# ----> 4 vgg16 = Sequential()
#       5 vgg16.add(Conv2D(64, kernel_size=3, padding='same', activation='relu',
#       6                  input_shape=(150, 150, 3)))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py in __init__(self, layers, name)
#     116     # Skip the init in FunctionalModel since model doesn't have input/output yet
#     117     super(functional.Functional, self).__init__(  # pylint: disable=bad-super-call
# --> 118         name=name, autocast=False)
#     119     base_layer.keras_api_gauge.get_cell('Sequential').set(True)
#     120     self.supports_masking = True
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in __init__(self, *args, **kwargs)
#     291     self._steps_per_execution = None
#     292
# --> 293     self._init_batch_counters()
#     294     self._base_model_initialized = True
#     295
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _init_batch_counters(self)
#     299     # `evaluate`, and `predict`.
#     300     agg = variables.VariableAggregationV2.ONLY_FIRST_REPLICA
# --> 301     self._train_counter = variables.Variable(0, dtype='int64', aggregation=agg)
#     302     self._test_counter = variables.Variable(0, dtype='int64', aggregation=agg)
#     303     self._predict_counter = variables.Variable(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
# --> 262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
#     264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py in _variable_v2_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape)
#     254         synchronization=synchronization,
#     255         aggregation=aggregation,
# --> 256         shape=shape)
#     257
#     258   def __call__(cls, *args, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py in <lambda>(**kws)
#     235                         shape=None):
#     236     """Call on Variable class. Useful to force the signature."""
# --> 237     previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#     238     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     239       previous_getter = _make_getter(getter, previous_getter)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variable_scope.py in default_variable_creator_v2(next_creator, **kwargs)
#    2665       synchronization=synchronization,
#    2666       aggregation=aggregation,
# -> 2667       shape=shape)
#    2668
#    2669
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1583           aggregation=aggregation,
#    1584           shape=shape,
# -> 1585           distribute_strategy=distribute_strategy)
#    1586
#    1587   def _init_from_args(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1717             initial_value = ops.convert_to_tensor(initial_value,
#    1718                                                   name="initial_value",
# -> 1719                                                   dtype=dtype)
#    1720           if shape is not None:
#    1721             if not initial_value.shape.is_compatible_with(shape):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      95     except AttributeError:
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# ---> 97   ctx.ensure_initialized()
#      98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/context.py in ensure_initialized(self)
#     524         if self._use_tfrt is not None:
#     525           pywrap_tfe.TFE_ContextOptionsSetTfrt(opts, self._use_tfrt)
# --> 526         context_handle = pywrap_tfe.TFE_NewContext(opts)
#     527       finally:
#     528         pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# KeyboardInterrupt:

# %%
vgg16.summary()

# %%
from keras.optimizers import SGD
sgd = SGD(lr=0.001, decay=1e-7, momentum=.9)
vgg16.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              metrics=['accuracy'])

# %%
trainingDataLabelY[0]

# %%
from keras.utils import to_categorical
trainingDataLabelOHE = to_categorical(trainingDataLabelY)
validationDataLabelOHE = to_categorical(validationDataLabelY)

# %%
trainingDataLabelOHE[0]

# %%
H = vgg16.fit(trainingDataImgX, trainingDataLabelOHE, batch_size=256, epochs=50, validation_data=(validationDataImgX, validationDataLabelOHE))
# Out:
# Epoch 1/50
# 44/44 [==============================] - 102s 2s/step - loss: 1.7814 - accuracy: 0.1998 - val_loss: 1.7537 - val_accuracy: 0.2301
# Epoch 2/50
# 44/44 [==============================] - 75s 2s/step - loss: 1.6773 - accuracy: 0.2967 - val_loss: 1.5582 - val_accuracy: 0.3473
# Epoch 3/50
# 44/44 [==============================] - 75s 2s/step - loss: 1.3527 - accuracy: 0.4551 - val_loss: 1.3069 - val_accuracy: 0.5023
# Epoch 4/50
# 44/44 [==============================] - 75s 2s/step - loss: 1.1657 - accuracy: 0.5312 - val_loss: 1.1374 - val_accuracy: 0.5900
# Epoch 5/50
# 44/44 [==============================] - 75s 2s/step - loss: 1.0890 - accuracy: 0.5632 - val_loss: 1.1118 - val_accuracy: 0.5672
# Epoch 6/50
# 44/44 [==============================] - 75s 2s/step - loss: 1.0253 - accuracy: 0.5900 - val_loss: 1.0736 - val_accuracy: 0.5686
# Epoch 7/50
# 44/44 [==============================] - 75s 2s/step - loss: 1.0152 - accuracy: 0.5891 - val_loss: 1.0667 - val_accuracy: 0.6017
# Epoch 8/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.9837 - accuracy: 0.6017 - val_loss: 1.0749 - val_accuracy: 0.5761
# Epoch 9/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.9494 - accuracy: 0.6145 - val_loss: 1.0113 - val_accuracy: 0.5921
# Epoch 10/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.9111 - accuracy: 0.6323 - val_loss: 0.9987 - val_accuracy: 0.6185
# Epoch 11/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.8999 - accuracy: 0.6399 - val_loss: 0.9280 - val_accuracy: 0.6405
# Epoch 12/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.8716 - accuracy: 0.6664 - val_loss: 0.9259 - val_accuracy: 0.6313
# Epoch 13/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.8547 - accuracy: 0.6701 - val_loss: 0.9592 - val_accuracy: 0.6413
# Epoch 14/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.8401 - accuracy: 0.6758 - val_loss: 0.8499 - val_accuracy: 0.6737
# Epoch 15/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.8179 - accuracy: 0.6855 - val_loss: 0.9383 - val_accuracy: 0.6380
# Epoch 16/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.8133 - accuracy: 0.6909 - val_loss: 0.8973 - val_accuracy: 0.6722
# Epoch 17/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.7343 - accuracy: 0.7240 - val_loss: 0.7689 - val_accuracy: 0.7228
# Epoch 18/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.7312 - accuracy: 0.7224 - val_loss: 0.9144 - val_accuracy: 0.6623
# Epoch 19/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.6896 - accuracy: 0.7476 - val_loss: 0.7973 - val_accuracy: 0.7104
# Epoch 20/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.6827 - accuracy: 0.7522 - val_loss: 0.7180 - val_accuracy: 0.7271
# Epoch 21/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.6625 - accuracy: 0.7616 - val_loss: 0.7095 - val_accuracy: 0.7471
# Epoch 22/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.6350 - accuracy: 0.7643 - val_loss: 0.7622 - val_accuracy: 0.7410
# Epoch 23/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.6215 - accuracy: 0.7744 - val_loss: 0.7828 - val_accuracy: 0.7154
# Epoch 24/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.5844 - accuracy: 0.7887 - val_loss: 0.7477 - val_accuracy: 0.7339
# Epoch 25/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.6045 - accuracy: 0.7771 - val_loss: 0.6732 - val_accuracy: 0.7563
# Epoch 26/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.6276 - accuracy: 0.7706 - val_loss: 0.6342 - val_accuracy: 0.7784
# Epoch 27/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.5567 - accuracy: 0.7968 - val_loss: 0.5648 - val_accuracy: 0.8019
# Epoch 28/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.5445 - accuracy: 0.7965 - val_loss: 0.5929 - val_accuracy: 0.7912
# Epoch 29/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.5321 - accuracy: 0.8033 - val_loss: 0.6359 - val_accuracy: 0.7731
# Epoch 30/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.5234 - accuracy: 0.8090 - val_loss: 0.6101 - val_accuracy: 0.7838
# Epoch 31/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.5081 - accuracy: 0.8186 - val_loss: 0.5899 - val_accuracy: 0.7962
# Epoch 32/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4993 - accuracy: 0.8218 - val_loss: 0.6176 - val_accuracy: 0.7862
# Epoch 33/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4764 - accuracy: 0.8276 - val_loss: 0.5638 - val_accuracy: 0.7976
# Epoch 34/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4843 - accuracy: 0.8268 - val_loss: 0.5454 - val_accuracy: 0.8090
# Epoch 35/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4808 - accuracy: 0.8268 - val_loss: 0.5781 - val_accuracy: 0.7941
# Epoch 36/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4591 - accuracy: 0.8339 - val_loss: 0.5124 - val_accuracy: 0.8351
# Epoch 37/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4589 - accuracy: 0.8357 - val_loss: 0.5095 - val_accuracy: 0.8204
# Epoch 38/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4387 - accuracy: 0.8424 - val_loss: 0.5443 - val_accuracy: 0.8183
# Epoch 39/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4465 - accuracy: 0.8352 - val_loss: 0.4978 - val_accuracy: 0.8283
# Epoch 40/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4263 - accuracy: 0.8481 - val_loss: 0.5424 - val_accuracy: 0.8155
# Epoch 41/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4311 - accuracy: 0.8451 - val_loss: 0.5885 - val_accuracy: 0.7962
# Epoch 42/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4128 - accuracy: 0.8498 - val_loss: 0.5158 - val_accuracy: 0.8180
# Epoch 43/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4032 - accuracy: 0.8508 - val_loss: 0.4838 - val_accuracy: 0.8368
# Epoch 44/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.4029 - accuracy: 0.8590 - val_loss: 0.4784 - val_accuracy: 0.8386
# Epoch 45/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.3977 - accuracy: 0.8599 - val_loss: 0.4909 - val_accuracy: 0.8390
# Epoch 46/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.3989 - accuracy: 0.8585 - val_loss: 0.5104 - val_accuracy: 0.8183
# Epoch 47/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.3834 - accuracy: 0.8638 - val_loss: 0.5710 - val_accuracy: 0.8087
# Epoch 48/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.3846 - accuracy: 0.8650 - val_loss: 0.5033 - val_accuracy: 0.8333
# Epoch 49/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.3651 - accuracy: 0.8654 - val_loss: 0.5115 - val_accuracy: 0.8222
# Epoch 50/50
# 44/44 [==============================] - 75s 2s/step - loss: 0.3553 - accuracy: 0.8696 - val_loss: 0.4554 - val_accuracy: 0.8408

# %%
# save the model's trained weights
vgg16.save_weights('vgg_trained_without_dropout.h5')

# %%
#!cp /content/vgg16_trained_normal_vgg.h5 /content/drive/MyDrive/Semester1/CV/Assignment/3
# Out:
# cp: cannot stat '/content/vgg16_trained_normal_vgg.h5': No such file or directory

# %%
import matplotlib.pyplot as plt
N = np.arange(0, 50)
plt.style.use('ggplot')
plt.figure()
plt.plot(N, H.history['loss'], label='train_loss')
plt.plot(N, H.history['val_loss'], label='val_loss')
plt.plot(N, H.history['accuracy'], label='train_accuracy')
plt.plot(N, H.history['val_accuracy'], label='val_accuracy')
plt.title('Training loss and accuracy')
plt.xlabel('Epoch #')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show()

# %%
testDataImgArr = np.array(list(map(readAndPreprocessImage, testData.filenames)))
testDataLabel = testData.target
testDataLabelOHE = to_categorical(testDataLabel)

# %%
'''CONFUSION MATRIX'''
# Making prediction
predicatedTestDataY = vgg16.predict_classes(testDataImgArr)
actualTestDataY = np.argmax(testDataLabelOHE, axis=-1)

# Plotting the confusion matrix
from sklearn.metrics import confusion_matrix
confusionMatrix = confusion_matrix(actualTestDataY, predicatedTestDataY)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(confusionMatrix)
# Out:
# [[365  14   3   1   8  46]
#  [  0 459   2   4   1   8]
#  [  6   6 440  51  47   3]
#  [ 13  12  65 394  41   0]
#  [ 10   4  19  13 461   3]
#  [ 50  20   1   1   7 422]]
